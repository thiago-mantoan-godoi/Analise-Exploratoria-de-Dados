# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from imblearn.over_sampling import SMOTE

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from IPython.core.display import display, HTML

# %% [markdown]
# ## Carregar o conjunto de dados

# %%
df = pd.read_csv("Datasets/manufacturing_defect_dataset.csv")

# %% [markdown]
# Exibir as primeiras linhas do dataframe

# %%
df.head()
# Out:
#    ProductionVolume  ProductionCost  SupplierQuality  DeliveryDelay  \
# 0               202    13175.403783        86.648534              1
# 1               535    19770.046093        86.310664              4
# 2               960    19060.820997        82.132472              0
# 3               370     5647.606037        87.335966              5
# 4               206     7472.222236        81.989893              3
#
#    DefectRate  QualityScore  MaintenanceHours  DowntimePercentage  \
# 0    3.121492     63.463494                 9            0.052343
# 1    0.819531     83.697818                20            4.908328
# 2    4.514504     90.350550                 1            2.464923
# 3    0.638524     67.628690                 8            4.692476
# 4    3.867784     82.728334                 9            2.746726
#
#    InventoryTurnover  StockoutRate  WorkerProductivity  SafetyIncidents  \
# 0           8.630515      0.081322           85.042379                0
# ...

# %% [markdown]
# Estatísticas descritivas do dataframe

# %%
df.describe()
# Out:
#        ProductionVolume  ProductionCost  SupplierQuality  DeliveryDelay  \
# count       3240.000000     3240.000000      3240.000000    3240.000000
# mean         548.523148    12423.018476        89.833290       2.558951
# std          262.402073     4308.051904         5.759143       1.705804
# min          100.000000     5000.174521        80.004820       0.000000
# 25%          322.000000     8728.829280        84.869219       1.000000
# 50%          549.000000    12405.204656        89.704861       3.000000
# 75%          775.250000    16124.462428        94.789936       4.000000
# max          999.000000    19993.365549        99.989214       5.000000
#
#         DefectRate  QualityScore  MaintenanceHours  DowntimePercentage  \
# count  3240.000000   3240.000000       3240.000000         3240.000000
# mean      2.749116     80.134272         11.476543            2.501373
# std       1.310154     11.611750          6.872684            1.443684
# ...

# %% [markdown]
# Dimensões do dataframe

# %%
df.shape
# Out:
# (3240, 17)

# %% [markdown]
# ## Verificar valores ausentes

# %%
df.isna().sum()
# Out:
# ProductionVolume        0
# ProductionCost          0
# SupplierQuality         0
# DeliveryDelay           0
# DefectRate              0
# QualityScore            0
# MaintenanceHours        0
# DowntimePercentage      0
# InventoryTurnover       0
# StockoutRate            0
# WorkerProductivity      0
# SafetyIncidents         0
# EnergyConsumption       0
# EnergyEfficiency        0
# AdditiveProcessTime     0
# AdditiveMaterialCost    0
# DefectStatus            0
# dtype: int64

# %% [markdown]
# ## Visualização da distribuição do status de defeito

# %%
fig, axes = plt.subplots(ncols=2, figsize=(15, 6))
index = 0

count = df["DefectStatus"].value_counts()
count.plot(kind="bar", ax=axes[index])
for container in axes[index].containers:
    axes[index].bar_label(container)
axes[index].set_yticklabels(())
axes[index].set_ylabel("")
axes[index].set_xlabel("")

index += 1

count.plot(kind="pie", ax=axes[index], autopct="%0.2f%%")
axes[index].set_ylabel("")
axes[index].set_xlabel("")

plt.show()

# %% [markdown]
# ## Matriz de correlação

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_83de9_row0_col0, #T_83de9_row1_col1, #T_83de9_row2_col2, #T_83de9_row3_col3, #T_83de9_row4_col4, #T_83de9_row5_col5, #T_83de9_row6_col6, #T_83de9_row7_col7, #T_83de9_row8_col8, #T_83de9_row9_col9, #T_83de9_row10_col10, #T_83de9_row11_col11, #T_83de9_row12_col12, #T_83de9_row13_col13, #T_83de9_row14_col14, #T_83de9_row15_col15, #T_83de9_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_83de9_row0_col1, #T_83de9_row1_col14, #T_83de9_row6_col9, #T_83de9_row8_col12, #T_83de9_row9_col11, #T_83de9_row13_col3, #T_83de9_row15_col14 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ## Histograma das variáveis numéricas

# %%
nums = df.columns[:-1].tolist()

index = 0

for i in range(4):
    fig, axes = plt.subplots(ncols=4, figsize=(15, 6))
    for j in range(4):
        sns.histplot(df, x=nums[index], ax=axes[j], kde=True)
        axes[j].set_ylabel("")
        axes[j].set_xlabel("")
        axes[j].set_title(nums[index])
        index += 1
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Agrupar por status de defeito e visualizar boxplots

# %%
grouped = df.groupby("DefectStatus")

index = 0

for i in range(4):
    fig, axes = plt.subplots(ncols=4, figsize=(15, 6))
    for j in range(4):
        mean = grouped[nums[index]].mean()
        sns.barplot(x=mean.index, y=mean, ax=axes[j])
        for container in axes[j].containers:
            axes[j].bar_label(container)
        axes[j].set_yticklabels(())
        axes[j].set_xticklabels(axes[j].get_xticklabels(), rotation=90)
        axes[j].set_ylabel("")
        axes[j].set_xlabel("")
        axes[j].set_title(nums[index])
        index += 1
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Distribuição da densidade dos dados entre casos com defeito e sem defeito

# %%
index = 0

for i in range(4):
    fig, axes = plt.subplots(ncols=4, figsize=(15, 6))
    for j in range(4):
        sns.kdeplot(df, x=nums[index], hue=df.columns[-1], ax=axes[j])
        axes[j].set_ylabel("")
        axes[j].set_xlabel("")
        axes[j].set_title(nums[index])
        index += 1
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Valores escalados

# %%
x = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

scaler = MinMaxScaler()

x = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42, test_size=0.2)

# %% [markdown]
# ## Tratando desequilíbrios de classe aplicando SMOTE

# %%
from collections import Counter

print("Before: ", Counter(y_train))

smote = SMOTE()

x_train, y_train = smote.fit_resample(x_train, y_train)

print("After: ", Counter(y_train))
# Out:
# Before:  Counter({1: 2177, 0: 415})
# After:  Counter({1: 2177, 0: 2177})

# %% [markdown]
# ## Feature definidas usando Random Forest

# %%
forest = RandomForestClassifier()

forest.fit(x_train, y_train)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)


forest_importances = pd.Series(importances, index=df.columns[:-1])

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %%
def training(model):
    model.fit(x_train, y_train)
    pred = model.predict(x_test)
    score = accuracy_score(pred, y_test)
    report = classification_report(pred, y_test)
    cm = confusion_matrix(pred, y_test)
    
    return score*100, report, cm

# %% [markdown]
# ## Modelos definidos

# %%
rfc = RandomForestClassifier()
etc = ExtraTreesClassifier()
abc = AdaBoostClassifier()
gbc = GradientBoostingClassifier()
lgr = LogisticRegression()
svc = SVC()
xgb = XGBClassifier()
lgb = LGBMClassifier()

models = [rfc, etc, abc, gbc,
         lgr, svc, xgb, lgb]

names = ["Random Forest", "Extra Trees", "Ada Boost", "Gradient Boosting",
        "Logistic Regression", "Support Vector Machine", "XGBoost", "LightGBM"]

# %% [markdown]
# ## Treinamento e salvamento de modelos: métricas de avaliação de desempenho

# %%
scores, reports, cms = [], dict(), dict()

for i, j in zip(models, names):
    score, report, cm = training(i)
    scores += [score]
    reports[j] = report
    cms[j] = cm
# Out:
# [LightGBM] [Info] Number of positive: 2177, number of negative: 2177
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002693 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4080
# [LightGBM] [Info] Number of data points in the train set: 4354, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000

# %% [markdown]
# ## Modelos classificados com base na sua precisão

# %%
dd = pd.DataFrame({"scores": scores}, index=names)
dd = dd.sort_values("scores", ascending=False)
dd["scores"] = round(dd["scores"], 2)

fig, axes = plt.subplots()

sns.barplot(x=dd.index, y=dd.iloc[:, 0], ax=axes)
for container in axes.containers:
    axes.bar_label(container)
axes.set_yticklabels(())
axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
axes.set_ylabel("")
axes.set_xlabel("")
plt.show()

# %% [markdown]
# ## Matrizes de confusão para as respectivas matrizes

# %%
index = 0

for i in range(2):
    fig, axes = plt.subplots(ncols=4, figsize=(15, 6))
    
    for j in range(4):
        sns.heatmap(cms[dd.index[index]], ax=axes[j], annot=True, fmt='d')
        axes[j].set_title("{}: {}%".format(dd.index[index], dd.iloc[index, 0]))
        index += 1
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Relatório de avaliação de classificação detalhado para os modelos correspondentes

# %%
for i in dd.index:
    print("*"*30)
    print(i)
    print(reports[i])
    print("\n\n")
# Out:
# ******************************
# LightGBM
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84        86
#            1       0.99      0.96      0.97       562
#
#     accuracy                           0.95       648
#    macro avg       0.88      0.94      0.91       648
# weighted avg       0.96      0.95      0.96       648
#
#
#
#
# ******************************
# Random Forest
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.84        87
#            1       0.99      0.96      0.97       561
#
#     accuracy                           0.95       648
#    macro avg       0.88      0.93      0.90       648
# weighted avg       0.96      0.95      0.95       648
#
#
#
#
# ******************************
# XGBoost
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.84        87
# ...
